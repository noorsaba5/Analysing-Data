# %% [markdown]
# <a href="https://colab.research.google.com/github/noorsaba5/Analysing-Data/blob/main/Employee_data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Task
# Tell me about this dataset.
#
# Here is all the data you need:
# "employees.csv"

# %% [markdown]
# ## Data loading
#
# ### Subtask:
# Load the employee data from the "employees.csv" file.

# %% [markdown]
# **Reasoning**:
# Load the employee data from the "employees.csv" file into a pandas DataFrame and display the first 5 rows.

# %%
import pandas as pd

try:
    df_employees = pd.read_csv('employees.csv')
    display(df_employees.head())
except FileNotFoundError:
    print("Error: 'employees.csv' not found. Please ensure the file exists in the current directory.")
    df_employees = None
except pd.errors.EmptyDataError:
    print("Error: 'employees.csv' is empty.")
    df_employees = None
except pd.errors.ParserError:
    print("Error: 'employees.csv' parsing error. Please check the file format.")
    df_employees = None
except Exception as e:
    print(f"An unexpected error occurred: {e}")
    df_employees = None
# Out:
#   Employee Name          Job Title       Department            Email Address
# 0      John Doe  Software Engineer               IT     john.doe@example.com
# 1    Jane Smith       Data Analyst        Analytics   jane.smith@example.com
# 2      John Doe  Software Engineer               IT     john.doe@example.com
# 3    Jane Smith       Data Analyst        Analytics   jane.smith@example.com
# 4   Bob Johnson         HR Manager  Human Resources  bob.johnson@example.com

# %% [markdown]
# ## Data exploration
#
# ### Subtask:
# Explore the loaded employee data to understand its basic characteristics.

# %% [markdown]
# **Reasoning**:
# Explore the basic characteristics of the employee data by checking its shape, data types, descriptive statistics, and value counts for categorical columns.

# %%
# Check the shape of the DataFrame
print("Shape of the DataFrame:", df_employees.shape)

# Examine the data types of each column
print("\nData Types of each column:\n", df_employees.dtypes)

# Generate descriptive statistics for numerical columns
print("\nDescriptive statistics for numerical columns:\n", df_employees.describe(include='number'))

# For categorical columns, understand the distribution of unique values
categorical_cols = df_employees.select_dtypes(include=['object']).columns
for col in categorical_cols:
    print(f"\nValue counts for {col}:\n{df_employees[col].value_counts()}")
# Out:
# Shape of the DataFrame: (25, 4)
#
# Data Types of each column:
#  Employee Name    object
# Job Title        object
# Department       object
# Email Address    object
# dtype: object
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-2-f7f28a21f572> in <cell line: 0>()
#       6
#       7 # Generate descriptive statistics for numerical columns
# ----> 8 print("\nDescriptive statistics for numerical columns:\n", df_employees.describe(include='number'))
#       9
#      10 # For categorical columns, understand the distribution of unique values
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/generic.py in describe(self, percentiles, include, exclude)
#   11974         max            NaN      3.0
#   11975         """
# > 11976         return describe_ndframe(
#   11977             obj=self,
#   11978             include=include,
#
# ...

# %% [markdown]
# ## Data analysis
#
# ### Subtask:
# Analyze the employee data to identify patterns and potential issues.

# %% [markdown]
# **Reasoning**:
# Analyze the distribution of employees across departments, the frequency of job titles, check for missing values, and identify potential outliers in the categorical columns.

# %%
# Department distribution
department_counts = df_employees['Department'].value_counts()
department_percentages = (department_counts / len(df_employees)) * 100
print("Department Distribution:\n", department_counts)
print("\nDepartment Percentages:\n", department_percentages)

# Job title frequency
job_title_counts = df_employees['Job Title'].value_counts()
print("\nJob Title Frequency:\n", job_title_counts)

# Missing values
missing_values = df_employees.isnull().sum()
missing_percentages = (missing_values / len(df_employees)) * 100
print("\nMissing Values:\n", missing_values)
print("\nMissing Value Percentages:\n", missing_percentages)

# Potential outliers (unusual entries in categorical columns)
# Check for unusually long job titles or department names.
print("\nPotential Outliers:")
for index, row in df_employees.iterrows():
    if len(row['Job Title']) > 50: # Example threshold
        print(f"Long Job Title: {row['Job Title']}")
    if len(row['Department']) > 20: # Example threshold
        print(f"Long Department Name: {row['Department']}")
    # Add other checks for email format, etc. as needed.
# Out:
# Department Distribution:
#  Department
# IT                 7
# Analytics          3
# Human Resources    2
# Marketing          2
# Business           2
# Finance            2
# Design             2
# Management         1
# Operations         1
# Sales              1
# Support            1
# Product            1
# Name: count, dtype: int64
#
# Department Percentages:
#  Department
# IT                 28.0
# Analytics          12.0
# Human Resources     8.0
# Marketing           8.0
# Business            8.0
# Finance             8.0
# Design              8.0
# Management          4.0
# Operations          4.0
# Sales               4.0
# Support             4.0
# Product             4.0
# Name: count, dtype: float64
#
# Job Title Frequency:
#  Job Title
# Software Engineer        2
# Data Analyst             2
# Content Writer           1
# Product Manager          1
# Technical Support        1
# Customer Service         1
# Sales Manager            1
# Graphic Designer         1
# ...

# %% [markdown]
# ## Data visualization
#
# ### Subtask:
# Visualize the key findings from the data exploration and analysis steps.

# %% [markdown]
# **Reasoning**:
# Create the visualizations specified in the instructions using matplotlib.

# %%
import matplotlib.pyplot as plt

# 1. Department Distribution
plt.figure(figsize=(10, 6))
df_employees['Department'].value_counts().plot(kind='bar', color='skyblue')
plt.title('Distribution of Employees Across Departments')
plt.xlabel('Department')
plt.ylabel('Number of Employees')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# 2. Job Title Frequency
plt.figure(figsize=(12, 6))
df_employees['Job Title'].value_counts().plot(kind='bar', color='lightcoral')
plt.title('Frequency of Different Job Titles')
plt.xlabel('Job Title')
plt.ylabel('Number of Employees')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# 3. Outlier Check (Optional - no outliers were found in the previous step)
# No visualization required as no outliers were identified in the data analysis.

# %% [markdown]
# ## Summary:
#
# ### 1. Q&A
#
# The provided data analysis does not explicitly pose questions. However, the analysis implicitly seeks to answer questions like:
#
# *   How are employees distributed across different departments?
# *   What are the most common job titles within the company?
# *   Are there any missing values or potential outliers in the data?
#
# Based on the analysis:
#
# *   The IT department has the highest number of employees (7, representing 28% of the total workforce).
# *   'Software Engineer' and 'Data Analyst' are the most frequent job titles.
# *   No missing values were found.  No outliers were found based on the length of job title and department name.
#
# ### 2. Data Analysis Key Findings
#
# *   **Department Distribution:** The IT department has the largest number of employees (7 employees, 28% of total).  The 'Analytics', 'Human Resources', 'Marketing', 'Business', 'Finance', and 'Design' departments have 2 employees each (8% each).
# *   **Job Title Frequency:** 'Software Engineer' and 'Data Analyst' are the most common job titles (each held by 2 employees).
# *   **No Missing Data:**  No missing values were detected in any of the columns.
# *   **No Outliers (based on length):** No unusually long job titles or department names were detected.
#
# ### 3. Insights or Next Steps
#
# *   **Investigate IT Department:** Given the significant concentration of employees in the IT department, further investigation into its activities and resource allocation might be beneficial.
# *   **Explore Other Outlier Types:** While no outliers were found based on length, explore other potential outliers using different criteria, like email format validation or unexpected characters in text fields.

# %%
import requests  # Import the requests library to make HTTP requests
from bs4 import BeautifulSoup  # Import BeautifulSoup for parsing HTML
import csv  # Import csv module for writing data to a CSV file
import pandas as pd  # Import pandas for data analysis
import matplotlib.pyplot as plt  # Import matplotlib for data visualization

# Function to scrape employee data from the given URL
def scrape_employee_data(url):
    # Send an HTTP GET request to the URL
    response = requests.get(url)

    # Check if the request was successful
    if response.status_code != 200:
        print("❌ Failed to retrieve the page. Status Code: {response.status_code}")
        return None

    # Parse the HTML content of the page using BeautifulSoup
    soup = BeautifulSoup(response.text, "html.parser")

    # Find the first table in the HTML page
    table = soup.find("table")
    if not table:
        print("❌ No table found on the webpage.")
        return None

    # Extract all rows from the table, skipping the header row
    rows = table.find_all("tr")[1:]

    # Initialize an empty list to store employee data
    employees = []

    # Loop through each row in the table and extract data
    for row in rows:
        cols = row.find_all("td")  # Find all columns (td elements) in the row
        if len(cols) == 4:  # Ensure the row has exactly 4 columns
            employees.append([
                cols[0].text.strip(),  # Employee Name
                cols[1].text.strip(),  # Job Title
                cols[2].text.strip(),  # Department
                cols[3].text.strip()   # Email Address
            ])

    return employees

# Function to save employee data to a CSV file
def save_to_csv(data, filename="employees.csv"):
    if not data:
        print("❌ No data to save.")
        return

    with open(filename, "w", newline="", encoding="utf-8") as file:
        writer = csv.writer(file)
        writer.writerow(["Employee Name", "Job Title", "Department", "Email Address"])  # Write header row
        writer.writerows(data)  # Write employee data

    print(f"✅ Data successfully scraped and saved to '{filename}'!")

# Function to analyze and visualize employee data
def analyze_and_visualize(data):
    if not data:
        print("❌ No data to analyze.")
        return

    # Load the data into a Pandas DataFrame
    df = pd.DataFrame(data, columns=["Employee Name", "Job Title", "Department", "Email Address"])

    # Data Analysis
    dept_counts = df["Department"].value_counts()  # Count employees per department
    job_counts = df["Job Title"].value_counts()  # Count employees per job title

    # Visualization - Display both graphs on the same page
    fig, axes = plt.subplots(1, 2, figsize=(15, 6))

    # Bar Chart - Employee Count by Department
    dept_counts.plot(kind="bar", color="skyblue", edgecolor="black", ax=axes[0])
    axes[0].set_title("Number of Employees per Department")
    axes[0].set_xlabel("Department")
    axes[0].set_ylabel("Number of Employees")
    axes[0].tick_params(axis='x', rotation=45)

    # Pie Chart - Job Title Distribution
    job_counts.plot(kind="pie", autopct="%1.1f%%", startangle=140, colors=["lightcoral", "gold", "lightblue", "lightgreen"], ax=axes[1])
    axes[1].set_title("Job Title Distribution")
    axes[1].set_ylabel("")

    # Adjust layout and display the figure
    plt.tight_layout()
    plt.show()

# Main execution block
if __name__ == "__main__":
    url = "http://darkmind.uk/SCRAPESITE/employees.html"  # Define the URL to scrape data from
    employee_data = scrape_employee_data(url)  # Scrape employee data
    save_to_csv(employee_data)  # Save data to CSV
    analyze_and_visualize(employee_data)  # Perform analysis and visualization

# %% [markdown]
# import requests  # Import the requests library to make HTTP requests
# from bs4 import BeautifulSoup  # Import BeautifulSoup for parsing HTML
# import csv  # Import csv module for writing data to a CSV file
# import pandas as pd  # Import pandas for data analysis
# import matplotlib.pyplot as plt  # Import matplotlib for data visualization
#
# # Function to scrape employee data from the given URL
# def scrape_employee_data(url):
#     # Send an HTTP GET request to the URL
#     response = requests.get(url)
#
#     # Check if the request was successful
#     if response.status_code != 200:
#         print("❌ Failed to retrieve the page. Status Code: {response.status_code}")
#         return None
#
#     # Parse the HTML content of the page using BeautifulSoup
#     soup = BeautifulSoup(response.text, "html.parser")
#
#     # Find the first table in the HTML page
#     table = soup.find("table")
#     if not table:
#         print("❌ No table found on the webpage.")
#         return None
#
#     # Extract all rows from the table, skipping the header row
#     rows = table.find_all("tr")[1:]
#
#     # Initialize an empty list to store employee data
#     employees = []
#
#     # Loop through each row in the table and extract data
#     for row in rows:
#         cols = row.find_all("td")  # Find all columns (td elements) in the row
#         if len(cols) == 4:  # Ensure the row has exactly 4 columns
#             employees.append([
#                 cols[0].text.strip(),  # Employee Name
#                 cols[1].text.strip(),  # Job Title
#                 cols[2].text.strip(),  # Department
#                 cols[3].text.strip()   # Email Address
#             ])
#
#     return employees
#
# # Function to save employee data to a CSV file
# def save_to_csv(data, filename="employees.csv"):
#     if not data:
#         print("❌ No data to save.")
#         return
#
#     with open(filename, "w", newline="", encoding="utf-8") as file:
#         writer = csv.writer(file)
#         writer.writerow(["Employee Name", "Job Title", "Department", "Email Address"])  # Write header row
#         writer.writerows(data)  # Write employee data
#
#     print(f"✅ Data successfully scraped and saved to '{filename}'!")
#
# # Function to analyze and visualize employee data
# def analyze_and_visualize(data):
#     if not data:
#         print("❌ No data to analyze.")
#         return
#
#     # Load the data into a Pandas DataFrame
#     df = pd.DataFrame(data, columns=["Employee Name", "Job Title", "Department", "Email Address"])
#
#     # Data Analysis
#     dept_counts = df["Department"].value_counts()  # Count employees per department
#     job_counts = df["Job Title"].value_counts()  # Count employees per job title
#
#     # Visualization - Display both graphs on the same page
#     fig, axes = plt.subplots(1, 2, figsize=(15, 6))
#
#     # Bar Chart - Employee Count by Department
#     dept_counts.plot(kind="bar", color="skyblue", edgecolor="black", ax=axes[0])
#     axes[0].set_title("Number of Employees per Department")
#     axes[0].set_xlabel("Department")
#     axes[0].set_ylabel("Number of Employees")
#     axes[0].tick_params(axis='x', rotation=45)
#
#     # Pie Chart - Job Title Distribution
#     job_counts.plot(kind="pie", autopct="%1.1f%%", startangle=140, colors=["lightcoral", "gold", "lightblue", "lightgreen"], ax=axes[1])
#     axes[1].set_title("Job Title Distribution")
#     axes[1].set_ylabel("")
#
#     # Adjust layout and display the figure
#     plt.tight_layout()
#     plt.show()
#
# # Main execution block
# if __name__ == "__main__":
#     url = "http://darkmind.uk/SCRAPESITE/employees.html"  # Define the URL to scrape data from
#     employee_data = scrape_employee_data(url)  # Scrape employee data
#     save_to_csv(employee_data)  # Save data to CSV
#     analyze_and_visualize(employee_data)  # Perform analysis and visualization
